# %% [markdown]
# #Exerciso 2 --- Calculadora de Folha de Pagamento
# #====Crie um programa que simule o cálculo de salário líquido de um funcionário=====

# %%
nome_Do_Funcionario = input('por favor digite seu nome completo' )
salario_base = float(input('por favor digite seu salario exato com decimais'))
quantidade_De_Horas_Extras = int(input('por favor informe a quantidade de horas trabalhads'))

print(f'Muito obrigado por informar seus dados {nome_Do_Funcionario}')

# Calculadora para medir valor de hora extra
horas_de_trabalho_mes = 220
porcentual_hora_extra = 1.5
valor_hora_extra = (salario_base / 220) * 1.5
hora_extra_ganha = quantidade_De_Horas_Extras * valor_hora_extra
print (f'Voce trabalhou, {quantidade_De_Horas_Extras} e o valor ganho foi de, {hora_extra_ganha:.2f}')
salario_base_com_hora_extra = salario_base + hora_extra_ganha
print(f'Parabens Voce vai receber no seu salario {salario_base_com_hora_extra:.2f} por ser uma pessoa esforcada')

#Calculo de para pagar o valor a previdencia

calculo_inss_Desconto = (100 - 11) /100 #0.89 porncetual

Salario_com_desconto_inss = salario_base_com_hora_extra * calculo_inss_Desconto

print(f'Porem voce precisa pagar inss e seu salario com desconto ficara em {Salario_com_desconto_inss:.2f}')

#Agora precisamos saber si o funcionario tem mais de 3000.00 de salario e mais de 10 horas extras para lhe dar mais uma bonifacaçao

if salario_base_com_hora_extra >= 3000.00:
    print(True)
    print('parabens voce ganho uma dia de folga')

else:
    print('Voce pode trabalhar meio periodo na sexta-feira')
    print(false)
# Out:
# Muito obrigado por informar seus dados Isaac Trenard
# Voce trabalhou, 220 e o valor ganho foi de, 4500.00
# Parabens Voce vai receber no seu salario 7500.00 por ser uma pessoa esforcada
# Porem voce precisa pagar inss e seu salario com desconto ficara em 6675.00
# True
# parabens voce ganho uma dia de folga
