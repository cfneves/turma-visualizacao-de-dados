# %%
### Passos

## 1. Carregue o `base_rh.csv` com os parâmetros corretos e confirme que `Salario` é `float64`.

import pandas as pd              # biblioteca de análise de dados
import re                        # expressões regulares (para limpar texto)
from datetime import datetime    # para trabalhar com datas

CAMINHO = r'C:\Users\luiso\Downloads\SCTECH\turma-visualizacao-de-dados\aulas\semana_04\base_rh.csv'

df = pd.read_csv(CAMINHO, sep=';', encoding='cp1252', decimal=',')

print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ID_Funcionario  1000 non-null   int64
#  1   Nome            1000 non-null   str
#  2   Departamento    1000 non-null   str
#  3   Cargo           1000 non-null   str
#  4   Salario         1000 non-null   float64
#  5   Data_Admissao   1000 non-null   str
#  6   Genero          1000 non-null   str
#  7   Idade           1000 non-null   int64
#  8   Estado_Civil    1000 non-null   str
#  9   Status          1000 non-null   str
# dtypes: float64(1), int64(2), str(7)
# memory usage: 78.3 KB
# None

# %%
## Confirmando que Salário é float64

print(df['Salario'].dtype)
# Out:
# float64

# %%
## Diagnóstico de base de dados

#df.info()                   # Informações Gerais
df.describe().round(2)       # Estatísticas descritivas
#print(df.isnull().sum())    # Verificando se há valores nulos
# Out:
#        ID_Funcionario       Salario        Idade
# count     1000.000000   1000.000000  1000.000000
# mean       500.500000   8579.951780    41.399000
# std        288.819436   3657.365307    13.665817
# min          1.000000   2000.710000    18.000000
# 25%        250.750000   5564.545000    30.000000
# 50%        500.500000   8571.135000    41.000000
# 75%        750.250000  11554.630000    53.000000
# max       1000.000000  14954.510000    65.000000

# %% [markdown]
# **Os 3 problemas mais importantes que encontrei foram:**
#
# 1. A coluna Data_Admissao ainda está no formato string e precisa ser convertida para datetime
#
# 2. Existem possíveis diferenças salariais que precisam ser analisadas entre cargos e departamentos
#
# 3. Os dados ainda precisam de colunas derivadas para análise temporal, como ano de admissão e tempo de casa
